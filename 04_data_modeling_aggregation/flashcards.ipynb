# %% [markdown]
# # Flacards

# %%
# !pip install pandas ipywidgets
# Out:
# ...
#      -------------------------------------- 139.8/139.8 kB 1.7 MB/s eta 0:00:00
# ...
#      ------------------------------------- 914.9/914.9 kB 11.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.2/2.2 MB 15.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: comm
#     Found existing installation: comm 0.1.2
#     Uninstalling comm-0.1.2:
#       Successfully uninstalled comm-0.1.2
# ...

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
import pandas as pd
import random
import ipywidgets as widgets

df = pd.read_csv("flashcards.csv")
df.head()
# Out:
#                                             Question  \
# 0  In a relational data model, what type of relat...
# 1  Which Pandas function is used to join the Trad...
# 2  In a trades dataset, what does the `quantity` ...
# 3  What Pandas method is used to calculate aggreg...
# 4  How do you find the index of the row containin...
#
#                                               Answer
# 0                  A 1:n (one-to-many) relationship.
# 1                              The `merge` function.
# 2  The number of shares or units traded in a sing...
# 3                              The `groupby` method.
# 4                    By using the `idxmax` function.

# %%
import pandas as pd
import random
import ipywidgets as widgets
from IPython.display import display

# Load CSV
df = pd.read_csv("flashcards.csv")
df = df.sample(frac=1).reset_index(drop=True)

current_index = 0

card = widgets.HTML()
button_next = widgets.Button(description="Next 🎲")

def update_card():
    question = df.loc[current_index, "Question"]
    answer = df.loc[current_index, "Answer"]

    card.value = f"""
    <style>
    .scene {{
        width: 420px;
        height: 420px;
        perspective: 1200px;
        margin: 20px auto;
    }}

    .card {{
        width: 100%;
        height: 100%;
        position: relative;
        transition: transform 0.8s;
        transform-style: preserve-3d;
        cursor: pointer;
    }}

    .card.flipped {{
        transform: rotateY(180deg);
    }}

    .card-face {{
        position: absolute;
        width: 100%;
        height: 100%;
        backface-visibility: hidden;
        display: flex;
        align-items: center;
        justify-content: center;
        padding: 30px;
        box-sizing: border-box;
        border-radius: 20px;
        font-size: 22px;
        text-align: center;
        font-family: 'Segoe UI', sans-serif;
        box-shadow: 0 20px 40px rgba(0,0,0,0.25);
    }}

    .card-front {{
        background: linear-gradient(135deg, #667eea, #764ba2);
        color: white;
    }}

    .card-back {{
        background: linear-gradient(135deg, #43cea2, #185a9d);
        color: white;
        transform: rotateY(180deg);
    }}
    </style>

    <div class="scene">
        <div class="card" onclick="this.classList.toggle('flipped')">
            <div class="card-face card-front">
                {question}
            </div>
            <div class="card-face card-back">
                {answer}
            </div>
        </div>
    </div>
    """

def next_card(b):
    global current_index
    current_index = random.randint(0, len(df)-1)
    update_card()

button_next.on_click(next_card)

update_card()

display(card, button_next)
# Out:
# HTML(value='\n    <style>\n    .scene {\n        width: 420px;\n        height: 420px;\n        perspective: 1…
# Button(description='Next 🎲', style=ButtonStyle())
