# %%
import random

animals = random.sample(['Lion', 'Elephant', 'Giraffe', 'Zebra', 'Monkey', 'Tiger', 'Bear', 'Dolphin', 'Penguin', 'Parrot'], 5)
print(animals)
# Out:
# ['Bear', 'Monkey', 'Penguin', 'Giraffe', 'Zebra']
